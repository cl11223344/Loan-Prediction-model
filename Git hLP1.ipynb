# %% [markdown]
# **Importing The Required Libraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# Checking out the Training Data

# %%
train_df=pd.read_csv('Train Data.csv')

# %%
train_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
train_df.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
train_df = train_df.dropna(axis=0)

# %%
train_df.isna().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
train_df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       480.000000         480.000000  480.000000        480.000000
# mean       5364.231250        3995.966500  144.735417        342.050000
# std        5668.251251        3658.977258   80.508164         65.212401
# min         150.000000          16.120001    9.000000         36.000000
# 25%        2898.750000        2054.000000  100.000000        360.000000
# 50%        3859.000000        4989.500000  128.000000        360.000000
# 75%        5852.500000        5000.000000  170.000000        360.000000
# max       81000.000000       55000.000000  600.000000        480.000000
#
#        Credit_History
# count      480.000000
# mean         0.854167
# std          0.353307
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
sns.countplot(train_df['Loan_Status'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
pd.crosstab(train_df['Credit_History'],train_df['Loan_Status'])
# Out:
# Loan_Status      N    Y
# Credit_History
# 0.0             63    7
# 1.0             85  325

# %%
train_df.boxplot(column='ApplicantIncome')

# %%
train_df["ApplicantIncome"].plot(kind = 'hist')

# %%
train_df["CoapplicantIncome"].plot(kind = 'hist')

# %%
train_df.boxplot(column='ApplicantIncome', by='Education')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
train_df.boxplot(column='LoanAmount')

# %%
train_df["LoanAmount"].plot(kind = 'hist')

# %%
train_df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
train_df['TotalIncome']=train_df['ApplicantIncome']+train_df['CoapplicantIncome']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
pd.set_option('display.max_columns', None)
train_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
train_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
! pip install sklearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
gender_columns = pd.get_dummies(train_df['Gender'], prefix='Gender')
print(gender_columns)
train_df = pd.concat([train_df, gender_columns], axis=1)
train_df = train_df.drop(columns=['Gender'])
# Out:
#      Gender_Female  Gender_Male
# 1                0            1
# 2                0            1
# 3                0            1
# 4                0            1
# 5                0            1
# ..             ...          ...
# 609              1            0
# 610              0            1
# 611              0            1
# 612              0            1
# 613              1            0
#
# [480 rows x 2 columns]

# %%
married_columns = pd.get_dummies(train_df['Married'], prefix='Married')
print(married_columns)
train_df = pd.concat([train_df, married_columns], axis=1)
train_df = train_df.drop(columns=['Married'])
# Out:
#      Married_No  Married_Yes
# 1             0            1
# 2             0            1
# 3             0            1
# 4             1            0
# 5             0            1
# ..          ...          ...
# 609           1            0
# 610           0            1
# 611           0            1
# 612           0            1
# 613           1            0
#
# [480 rows x 2 columns]

# %%
dependents_columns = pd.get_dummies(train_df['Dependents'], prefix='Dependents')
print(dependents_columns)
train_df = pd.concat([train_df, dependents_columns], axis=1)
train_df = train_df.drop(columns=['Dependents'])
# Out:
#      Dependents_0  Dependents_1  Dependents_2  Dependents_3+
# 1               0             1             0              0
# 2               1             0             0              0
# 3               1             0             0              0
# 4               1             0             0              0
# 5               0             0             1              0
# ..            ...           ...           ...            ...
# 609             1             0             0              0
# 610             0             0             0              1
# 611             0             1             0              0
# 612             0             0             1              0
# 613             1             0             0              0
#
# [480 rows x 4 columns]

# %%
education_columns = pd.get_dummies(train_df['Education'], prefix='Education')
print(education_columns)
train_df = pd.concat([train_df, education_columns], axis=1)
train_df = train_df.drop(columns=['Education'])
# Out:
#      Education_Graduate  Education_Not Graduate
# 1                     1                       0
# 2                     1                       0
# 3                     0                       1
# 4                     1                       0
# 5                     1                       0
# ..                  ...                     ...
# 609                   1                       0
# 610                   1                       0
# 611                   1                       0
# 612                   1                       0
# 613                   1                       0
#
# [480 rows x 2 columns]

# %%
self_employed_columns = pd.get_dummies(train_df['Self_Employed'], prefix='Self_Employed')
print(self_employed_columns)
train_df = pd.concat([train_df, self_employed_columns], axis=1)
train_df = train_df.drop(columns=['Self_Employed'])
# Out:
#      Self_Employed_No  Self_Employed_Yes
# 1                   1                  0
# 2                   0                  1
# 3                   1                  0
# 4                   1                  0
# 5                   0                  1
# ..                ...                ...
# 609                 1                  0
# 610                 1                  0
# 611                 1                  0
# 612                 1                  0
# 613                 0                  1
#
# [480 rows x 2 columns]

# %%
property_area_columns = pd.get_dummies(train_df['Property_Area'], prefix='Property_Area')
print(property_area_columns)
train_df = pd.concat([train_df, property_area_columns], axis=1)
train_df = train_df.drop(columns=['Property_Area'])
# Out:
#      Property_Area_Rural  Property_Area_Semiurban  Property_Area_Urban
# 1                      1                        0                    0
# 2                      0                        0                    1
# 3                      0                        0                    1
# 4                      0                        0                    1
# 5                      0                        0                    1
# ..                   ...                      ...                  ...
# 609                    1                        0                    0
# 610                    1                        0                    0
# 611                    0                        0                    1
# 612                    0                        0                    1
# 613                    0                        1                    0
#
# [480 rows x 3 columns]

# %%
train_df = train_df.drop(columns=['Loan_ID'])

# %%
train_df.isna().sum()
# Out:
# ApplicantIncome            0
# CoapplicantIncome          0
# LoanAmount                 0
# Loan_Amount_Term           0
# Credit_History             0
# Loan_Status                0
# TotalIncome                0
# Gender_Female              0
# Gender_Male                0
# Married_No                 0
# Married_Yes                0
# Dependents_0               0
# Dependents_1               0
# Dependents_2               0
# Dependents_3+              0
# Education_Graduate         0
# Education_Not Graduate     0
# Self_Employed_No           0
# Self_Employed_Yes          0
# Property_Area_Rural        0
# Property_Area_Semiurban    0
# Property_Area_Urban        0
# dtype: int64

# %%
train_df.columns
# Out:
# Index(['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Loan_Status', 'TotalIncome',
#        'Gender_Female', 'Gender_Male', 'Married_No', 'Married_Yes',
#        'Dependents_0', 'Dependents_1', 'Dependents_2', 'Dependents_3+',
#        'Education_Graduate', 'Education_Not Graduate', 'Self_Employed_No',
#        'Self_Employed_Yes', 'Property_Area_Rural', 'Property_Area_Semiurban',
#        'Property_Area_Urban'],
#       dtype='object')

# %%
Y=train_df["Loan_Status"]
X=train_df.drop(columns=['Loan_Status'])

# %%
from sklearn.model_selection import train_test_split

dimple1, dimple2, dimple3, dimple4= train_test_split(X, Y, test_size=0.3)

# %%
dimple3 = pd.DataFrame(dimple3)
dimple4=pd.DataFrame(dimple4)

# %%
dimple1.head()
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 71              1875             1875.0        97.0             360.0
# 119            10408             5000.0       259.0             360.0
# 225             3250             5000.0       170.0             360.0
# 227             6250             1695.0       210.0             360.0
# 327             5818             2160.0       184.0             360.0
#
#      Credit_History  TotalIncome  Gender_Female  Gender_Male  Married_No  \
# 71              1.0       3750.0              0            1           0
# 119             1.0      15408.0              1            0           1
# 225             1.0       8250.0              0            1           0
# 227             1.0       7945.0              0            1           0
# 327             1.0       7978.0              0            1           0
#
#      Married_Yes  Dependents_0  Dependents_1  Dependents_2  Dependents_3+  \
# ...

# %%
dimple3.head()
# Out:
#     Loan_Status
# 71            Y
# 119           Y
# 225           N
# 227           Y
# 327           Y

# %%
dimple2.head()
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 388             2333             2417.0       136.0             360.0
# 604            12000             5000.0       496.0             360.0
# 452             3948             1733.0       149.0             360.0
# 27              4226             1040.0       110.0             360.0
# 575             3159              461.0       108.0              84.0
#
#      Credit_History  TotalIncome  Gender_Female  Gender_Male  Married_No  \
# 388             1.0       4750.0              0            1           0
# 604             1.0      17000.0              1            0           0
# 452             0.0       5681.0              0            1           0
# 27              1.0       5266.0              0            1           0
# 575             1.0       3620.0              0            1           0
#
#      Married_Yes  Dependents_0  Dependents_1  Dependents_2  Dependents_3+  \
# ...

# %%
dimple4.head()
# Out:
#     Loan_Status
# 388           Y
# 604           Y
# 452           N
# 27            Y
# 575           Y

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(max_depth=8)
dt.fit(dimple1,dimple3)
# Out:
# DecisionTreeClassifier(max_depth=8)

# %% [markdown]
# Underfitting

# %%
# For DT classifier
import numpy as np
from matplotlib import pyplot

# Some functions to plot our points and draw the models
def plot_points(features, labels, size_of_points=100):
    X = np.array(features)
    y = np.array(labels)
    spam = X[np.argwhere(y==1)]
    ham = X[np.argwhere(y==0)]
    pyplot.scatter([s[0][0] for s in spam],
                [s[0][1] for s in spam],
                s = size_of_points,
                color = 'cyan',
                edgecolor = 'k',
                marker = '^')
    pyplot.scatter([s[0][0] for s in ham],
                [s[0][1] for s in ham],
                s = size_of_points,
                color = 'red',
                edgecolor = 'k',
                marker = 's')

def plot_model(X, y, model, size_of_points=100):
    X = np.array(X)
    y = np.array(y)
    plot_step = 0.2
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step),
                         np.arange(y_min, y_max, plot_step))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    pyplot.contourf(xx, yy, Z, colors=['red', 'blue'], alpha=0.2, levels=range(-1,2))
    pyplot.contour(xx, yy, Z,colors = 'k',linewidths = 1)
    plot_points(X, y, size_of_points)
    pyplot.show()
    
def display_tree(dt):
    from six import StringIO  
    from IPython.display import Image  
    from sklearn.tree import export_graphviz
    import pydotplus
    dot_data = StringIO()
    export_graphviz(dt, out_file=dot_data,  
                    filled=True, rounded=True,
                    special_characters=True)
    graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
    return Image(graph.create_png())

# %%
uf_dt=DecisionTreeClassifier(max_depth=3)
uf_dt.fit(dimple1, dimple3)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
display_tree(uf_dt)

# %% [markdown]
# Overfitting

# %%
of_dt = DecisionTreeClassifier()
of_dt.fit(dimple1, dimple3)
# Out:
# DecisionTreeClassifier()

# %%
display_tree(of_dt)

# %% [markdown]
# **Correctly graphed with max_depth controlled**

# %%
display_tree(dt)

# %%
dt.score(dimple1, dimple3)
# Out:
# 0.9077380952380952

# %%
dimple5_predictions=dt.predict(dimple2)

# %%
dimple5_predictions = pd.DataFrame(dimple5_predictions)

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(dimple4, dimple5_predictions)
# Out:
# array([[21, 26],
#        [ 7, 90]])

# %%
from sklearn.metrics import classification_report

print(classification_report(dimple4, dimple5_predictions, target_names=["Y", "N"]))
# Out:
#               precision    recall  f1-score   support
#
#            Y       0.75      0.45      0.56        47
#            N       0.78      0.93      0.85        97
#
#     accuracy                           0.77       144
#    macro avg       0.76      0.69      0.70       144
# weighted avg       0.77      0.77      0.75       144

# %%
from sklearn.metrics import RocCurveDisplay

RocCurveDisplay.from_estimator(dt, dimple2, dimple4)

# %%
from sklearn.model_selection import KFold 

kf = KFold(n_splits=5, random_state=None)
kf.get_n_splits(X)
acc_score = []

for train_index , test_index in kf.split(X):
    X_train , X_test = X.iloc[train_index], X.iloc[test_index]
    y_train , y_test = Y.iloc[train_index], Y.iloc[test_index]
     
    dt.fit(X_train,y_train)
    pred_values = dt.predict(X_test)
    
    acc = f1_score(pred_values , y_test, pos_label="Y")
    acc_score.append(acc)
     
avg_acc_score = sum(acc_score)/5
 
print('accuracy of each fold - {}'.format(acc_score))
print('Avg accuracy : {}'.format(avg_acc_score))
# Out:
# accuracy of each fold - [0.8208955223880597, 0.7972972972972973, 0.8493150684931507, 0.8592592592592593, 0.8467153284671534]
# Avg accuracy : 0.8346964951809841

# %%
from sklearn.naive_bayes import GaussianNB

dimples_naivebayes = GaussianNB()

# %%
dimples_naivebayes.fit(dimple1, dimple3)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB()

# %%
dimple6 = dimples_naivebayes.predict(dimple2)

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(dimple4, dimple6)
# Out:
# array([[23, 24],
#        [ 6, 91]])

# %%
from sklearn.metrics import classification_report

print(classification_report(dimple4, dimple6, target_names=["Y", "N"]))
# Out:
#               precision    recall  f1-score   support
#
#            Y       0.79      0.49      0.61        47
#            N       0.79      0.94      0.86        97
#
#     accuracy                           0.79       144
#    macro avg       0.79      0.71      0.73       144
# weighted avg       0.79      0.79      0.78       144

# %%
from sklearn.metrics import RocCurveDisplay

RocCurveDisplay.from_estimator(dimples_naivebayes, dimple2, dimple4)

# %%
from sklearn.model_selection import KFold 

kf = KFold(n_splits=5, random_state=None)
kf.get_n_splits(X)
acc_score = []

for train_index , test_index in kf.split(X):
    X_train , X_test = X.iloc[train_index], X.iloc[test_index]
    y_train , y_test = Y.iloc[train_index], Y.iloc[test_index]
     
    dimples_naivebayes.fit(X_train,y_train)
    pred_values = dimples_naivebayes.predict(X_test)
    
    acc = f1_score(pred_values , y_test, pos_label="Y")
    acc_score.append(acc)
     
avg_acc_score = sum(acc_score)/5
 
print('accuracy of each fold - {}'.format(acc_score))
print('Avg accuracy : {}'.format(avg_acc_score))
# Out:
# accuracy of each fold - [0.8391608391608392, 0.8194444444444445, 0.8783783783783784, 0.8823529411764706, 0.8309859154929579]
# Avg accuracy : 0.8500645037306181

# %%
from sklearn import neighbors
from sklearn.neighbors import KNeighborsClassifier
KNeighbors_Classifier = KNeighborsClassifier(n_neighbors=5)

# %%
#Compling model for KNeighbors_Classifier
KNeighbors_Classifier.fit(dimple1,dimple3)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
dimples_kneighbors=KNeighbors_Classifier.predict(dimple2)

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(dimple4, dimples_kneighbors)
# Out:
# array([[13, 34],
#        [20, 77]])

# %%
from sklearn.metrics import classification_report

print(classification_report(dimple4, dimples_kneighbors, target_names=["Y", "N"]))
# Out:
#               precision    recall  f1-score   support
#
#            Y       0.39      0.28      0.33        47
#            N       0.69      0.79      0.74        97
#
#     accuracy                           0.62       144
#    macro avg       0.54      0.54      0.53       144
# weighted avg       0.60      0.62      0.60       144

# %%
from sklearn.metrics import RocCurveDisplay

RocCurveDisplay.from_estimator(KNeighbors_Classifier, dimple2, dimple4)

# %%
from sklearn.model_selection import KFold 

kf = KFold(n_splits=5, random_state=None)
kf.get_n_splits(X)
acc_score = []

for train_index , test_index in kf.split(X):
    X_train , X_test = X.iloc[train_index], X.iloc[test_index]
    y_train , y_test = Y.iloc[train_index], Y.iloc[test_index]
     
    KNeighbors_Classifier.fit(X_train,y_train)
    pred_values = KNeighbors_Classifier.predict(X_test)
    
    acc = f1_score(pred_values , y_test, pos_label="Y")
    acc_score.append(acc)
     
avg_acc_score = sum(acc_score)/5
 
print('accuracy of each fold - {}'.format(acc_score))
print('Avg accuracy : {}'.format(avg_acc_score))
# Out:
# accuracy of each fold - [0.7843137254901961, 0.7462686567164178, 0.8211920529801324, 0.6956521739130435, 0.7517730496453902]
# Avg accuracy : 0.7598399317490359

# %%
#random forest
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
ranfor = RandomForestClassifier(max_depth=2, random_state=0)
ranfor.fit(dimple1, dimple3)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """
# RandomForestClassifier(max_depth=2, random_state=0)

# %%
v = ranfor.predict(dimple2)

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(dimple4, v)
# Out:
# array([[14, 33],
#        [ 0, 97]])

# %%
from sklearn.metrics import classification_report

print(classification_report(dimple4, v, target_names=["Y", "N"]))
# Out:
#               precision    recall  f1-score   support
#
#            Y       1.00      0.30      0.46        47
#            N       0.75      1.00      0.85        97
#
#     accuracy                           0.77       144
#    macro avg       0.87      0.65      0.66       144
# weighted avg       0.83      0.77      0.73       144

# %%
from sklearn.metrics import RocCurveDisplay

RocCurveDisplay.from_estimator(ranfor, dimple2, dimple4)

# %%
from sklearn.model_selection import KFold 

kf = KFold(n_splits=5, random_state=None)
kf.get_n_splits(X)
acc_score = []

for train_index , test_index in kf.split(X):
    X_train , X_test = X.iloc[train_index], X.iloc[test_index]
    y_train , y_test = Y.iloc[train_index], Y.iloc[test_index]
     
    ranfor.fit(X_train,y_train)
    pred_values = ranfor.predict(X_test)
    
    acc = f1_score(pred_values , y_test, pos_label="Y")
    acc_score.append(acc)
     
avg_acc_score = sum(acc_score)/5
 
print('accuracy of each fold - {}'.format(acc_score))
print('Avg accuracy : {}'.format(avg_acc_score))
# Out:
# accuracy of each fold - [0.8533333333333333, 0.8104575163398694, 0.8701298701298702, 0.87248322147651, 0.9078947368421052]
# Avg accuracy : 0.8628597356243375

# %%
# Adaboost
from sklearn.ensemble import AdaBoostClassifier
clf = AdaBoostClassifier(n_estimators=100, random_state=0)
clf.fit(dimple1, dimple3)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# AdaBoostClassifier(n_estimators=100, random_state=0)

# %%
dimples_adaboost=clf.predict(dimple2)

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(dimple4, dimples_adaboost)
# Out:
# array([[24, 23],
#        [10, 87]])

# %%
from sklearn.metrics import classification_report

print(classification_report(dimple4, dimples_adaboost, target_names=["Y", "N"]))
# Out:
#               precision    recall  f1-score   support
#
#            Y       0.71      0.51      0.59        47
#            N       0.79      0.90      0.84        97
#
#     accuracy                           0.77       144
#    macro avg       0.75      0.70      0.72       144
# weighted avg       0.76      0.77      0.76       144

# %%
from sklearn.metrics import RocCurveDisplay

RocCurveDisplay.from_estimator(clf, dimple2, dimple4)

# %%
from sklearn.model_selection import KFold 

kf = KFold(n_splits=5, random_state=None)
kf.get_n_splits(X)
acc_score = []

for train_index , test_index in kf.split(X):
    X_train , X_test = X.iloc[train_index], X.iloc[test_index]
    y_train , y_test = Y.iloc[train_index], Y.iloc[test_index]
     
    clf.fit(X_train,y_train)
    pred_values = clf.predict(X_test)
    
    acc = f1_score(pred_values , y_test, pos_label="Y")
    acc_score.append(acc)
     
avg_acc_score = sum(acc_score)/5
 
print('accuracy of each fold - {}'.format(acc_score))
print('Avg accuracy : {}'.format(avg_acc_score))
# Out:
# accuracy of each fold - [0.8059701492537313, 0.8378378378378379, 0.8689655172413794, 0.823529411764706, 0.823529411764706]
# Avg accuracy : 0.831966465572472
